    2.618337E+00, 2.398675E+00, 2.174743E+00, 1.973006E+00, 1.767542E+00,
    1.559136E+00, 1.388105E+00, 1.245415E+00, 1.106893E+00, 9.899717E-01,
    9.134314E-01, 8.420908E-01, 7.698313E-01, 7.170319E-01, 6.787253E-01,
    6.379317E-01, 6.056904E-01, 5.856277E-01, 5.618792E-01, 5.377198E-01,
    5.222762E-01, 5.089940E-01, 4.943599E-01, 4.838341E-01, 4.732544E-01,
    4.588599E-01, 4.485080E-01, 4.417946E-01, 4.331451E-01
]

# Define corresponding energy grid for the spectrum (assuming interval 0.001265 eV)
energy_interval = 0.001265
energy_grid = [i * energy_interval for i in range(len(spectrum_data))]

# Define additional delta peaks with (energy, weight, shape, width)
peaks = [
    (0.205, 2.0, "triangular", 0.01),  # Example triangular peak
    (0.436, 2.0, "gaussian", 0.01)    # Example Gaussian peak
]

# Initialize phonon spectrum with continuous data and optional peaks
ts.initialize_phonon_spectrum(energy_grid, spectrum_data, peaks)
# Out:
# 4.84621e-06 3.74987e-05
# 6.46159e-06 4.9998e-05
# 8.61539e-06 6.66635e-05
# 1.14872e-05 8.88846e-05
# 1.53162e-05 0.000118513
# 2.04213e-05 0.000158015
# 2.72294e-05 0.000210694
# 3.63056e-05 0.000280922
# 4.84071e-05 0.000374561
# 6.45425e-05 0.000499412
# 8.60573e-05 0.000665887
# 0.000114746 0.000887875
# 0.000152989 0.00118378
# 0.000203991 0.00157843
# 0.000271985 0.00210454
# 0.00036264 0.00280601
# 0.00048352 0.00374135
# 0.0006447 0.00498851
# 0.000859597 0.00665132
# 0.00114611 0.00886828
# 0.00152815 0.0118244
# 0.00203759 0.0157663
# 0.00271676 0.0210215
# 0.00362235 0.0280287
# 0.00482979 0.0373716
# 0.00965959 0.0747432
# 0.0144894 0.112115
# 0.0193192 0.149486
# 0.024149 0.186858
# 0.0289788 0.22423
# 0.0386383 0.298973
# 0.0482979 0.373716
# 0.0579575 0.486572
# 0.0676171 0.620737
# 0.0772767 0.754902
# 0.0965959 1.02323
# 0.120745 1.31215
# 0.144894 1.58235
# 0.169043 1.78142
# 0.193192 1.92675
# 0.217341 2.02262
# 0.24149 2.05191
# 0.289788 1.96876
# 0.338086 1.72969
# 0.386383 1.46067
# 0.434681 1.27652
# 0.482979 1.19514
# 0.531277 1.17732
# 0.579575 1.20559
# 0.627873 1.26016
# 0.676171 1.31276
# 0.724469 1.37244
# 0.772767 1.45233
# 0.821065 1.53284
# 0.869363 1.61485
# 0.917661 1.70906
# 0.965959 1.80499
# 1.01426 1.89096
# 1.06255 1.97959
# 1.11085 2.08023
# 1.15915 2.17758
# 1.20745 2.25093
# 1.25575 2.30218
# 1.30404 2.34808
# 1.35234 2.38197
# 1.40064 2.38102
# 1.44894 2.34334
# 1.49724 2.31189
# 1.54553 2.31445
# 1.59383 2.35328
# 1.64213 2.43106
# 1.69043 2.55636
# 1.73873 2.72348
# 1.78702 2.91874
# 1.83532 3.14425
# 1.88362 3.40799
# 1.93192 3.69999
# 1.98022 4.00712
# 2.02851 4.34603
# 2.07681 4.73274
# 2.12511 5.13118
# 2.17341 5.50528
# 2.2217 5.90212
# 2.27 6.32972
# 2.3183 6.73597
# 2.3666 7.10933
# 2.4149 7.47763
# 2.46319 7.81951
# 2.51149 8.09294
# 2.55979 8.30065
# 2.62036 8.50578
# 2.67571 8.59745
# 2.73366 8.56267
# 2.80128 8.48744
# 2.85924 8.43878
# 2.92685 8.31151
# 3.00413 8.07567
# 3.07175 7.82929
# 3.14903 7.57824
# 3.2263 7.32081
# 3.31324 6.99554
# 3.40017 6.7134
# 3.48711 6.3786
# 3.58371 6.03857
# 3.6803 5.70339
# 3.78656 5.35484
# 3.89281 4.95948
# 3.99907 4.59163
# 4.11498 4.20292
# 4.24056 3.81447
# 4.36613 3.48697
# 4.49171 3.11815
# 4.6366 2.6931
# 4.77184 2.13683
# 4.92639 1.52942
# 5.08094 1.08823
# 5.24081 0.824164
# 5.40937 0.658144
# 5.50596 0.598253
# 5.76677 0.503004
# 5.95997 0.457394
# 6.15316 0
# 6.36567 0
# 6.57818 0
# 6.80035 0
# 7.04184 0
# 7.28333 0
# 7.54414 0
# 7.63107 0
# 7.72767 0
# 7.82697 0
# 7.92086 0
# 7.99814 0.092906
# 8.08507 0.517829
# 8.37486 1.93424
# 8.67431 0.602138
# 8.98342 0
# 9.31184 0
# 9.65959 0
# 10.046 0
# 10.4468 3.91087e-307
# 10.7801 1.30286e-276
# 11.1761 2.0463e-242
# 11.5915 5.64114e-209
# 12.0358 5.99237e-176
# 12.5381 4.92048e-142
# 13.0675 3.20074e-110
# 13.4655 5.87707e-89
# 13.9871 1.54767e-64
# 14.5184 1.0954e-43
# 15.0883 7.80631e-26
# 15.6543 9.99861e-13
# 15.8446 2.35129e-09
# 16.2281 0.000382788
# 16.4213 0.0255424
# 16.9043 4.16289
# 17.5804 0.0120141
# 18.2759 4.04356e-12
# 18.7396 2.66882e-22
# 19.2709 9.11621e-38
# 19.9953 2.12098e-65
# 20.8937 3.77596e-110
# 21.3477 3.51783e-137
# 21.8886 2.94369e-173
# 22.7 2.89367e-235
# 23.4805 7.59983e-304
# 23.6718 5.43472e-322
# 23.9558 0
# 25.3081 0
# 26.1002 0
# 26.5639 0
# 27.0951 0
# 27.9162 0
# 28.718 0
# 29.172 0
# 29.7129 0
# 30.4277 0
# 31.3067 0
# 31.4989 0
# 31.6892 0
# 31.78 0
# 32.8426 0
# 34.0983 0
# 34.9194 0
# 35.3541 0
# 35.9143 0
# 36.6098 0
# 37.4792 0
# 38.5321 0
# 38.8315 0
# 39.1339 0
# 39.5164 0
# 39.6043 0
# 40.1259 0
# 40.5703 0
# 41.7294 0
# 42.6954 0
# 43.7386 0
# 44.4341 0
# 45.4001 0
# 46.3564 0
# 46.6558 0
# 46.9601 0
# 47.5339 0
# 47.9116 0
# 48.9451 0
# 49.4571 0
# 50.7128 0
# 51.5629 0
# 52.0652 0
# 52.5578 0
# 53.3209 0
# 54.0937 0
# 54.7892 0
# 55.1756 0
# 56.412 0
# 57.7643 0
# 59.1167 0
# 60.3821 0
# 61.6282 0
# 63.0095 0
# 64.2363 0
# 65.5886 0
# 66.0716 0
# 66.5835 0
# 67.4239 0
# 68.2063 0
# 68.6797 0
# 69.2013 0
# 69.7422 0
# 70.4377 0
# 70.8376 0
# 71.4809 0
# 72.2537 0
# 73.0265 0
# 73.7992 0
# 74.572 0
# 75.3448 0
# 76.2141 0
# 77.0835 0
# 77.9529 0
# 78.8222 0
# 79.6916 0
# 80.561 0
# 81.4303 0
# 82.2997 0
# 83.169 0
# 84.0384 0
# 85.0044 0
# 85.9703 0
# 86.9363 0
# 87.9022 0
# 88.8682 0
# 89.8342 0
# 90.8001 0
# 91.7661 0
# 92.732 0
# 93.698 0
# 94.664 0
# 95.6299 0
# 96.5959 0
# 97.755 0
# 98.9142 0
# 100.073 0
# 101.232 0
# 102.392 0
# 103.551 0
# 104.71 0
# 105.869 0
# 107.028 0
# 108.187 0
# 109.636 0
# 111.085 0
# 112.534 0
# 113.983 0
# 115.432 0
# 116.881 0
# 118.33 0
# 119.779 0
# 121.228 0
# 122.677 0
# 124.126 0
# 125.575 0
# 127.507 0
# 129.438 0
# 131.37 0
# 133.302 0
# 135.234 0
# 137.166 0
# 139.098 0
# 141.03 0
# 142.962 0
# 144.894 0
# 146.826 0
# 148.758 0
# 150.69 0
# 152.718 0
# 160.349 0
# 168.376 0
# 176.79 0
# 185.628 0
# 194.911 0
# 204.658 0
# 214.887 0
# 225.638 0
# 236.911 0
# 248.763 0
# 261.195 0
# 274.255 0
# 287.972 0
# 302.374 0
# 317.491 0
# 333.362 0
# 350.034 0
# 367.538 0
# 381.805 0
# p(beta) is scaled to 0.0405981

# %%
# Retrieve and plot the phonon spectrum
phonon_spectrum = ts.get_phonon_spectrum()

# Plotting
plt.plot(beta_grid, phonon_spectrum)
plt.xlabel("Beta")
plt.ylabel("Phonon Spectrum (rho_beta)")
plt.title("Phonon Spectrum")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
# Compute S(alpha, beta)
ts.compute_S_alpha_beta()

# Normalize and enforce symmetry
ts.normalize_S_alpha_beta()
ts.enforce_symmetry()

# Get S(alpha, beta) as a NumPy array
S_alpha_beta = ts.get_S_alpha_beta()

# %%
# Plot the S(alpha, beta) matrix as a heatmap
plt.figure(figsize=(10, 8))
plt.imshow(S_alpha_beta, extent=[beta_grid[0], beta_grid[-1], alpha_grid[0], alpha_grid[-1]],
           aspect='auto', origin='lower', cmap='viridis', norm=LogNorm(vmin=0.01, vmax=1))
plt.colorbar(label='S(alpha, beta)')
plt.xlabel('Beta')
plt.ylabel('Alpha')
plt.title('Scattering Law S(alpha, beta)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data with updated method
df = pd.read_csv('leapr_hinh2o.txt', sep='\s+', skiprows=1, names=['e', 'rho(e)', 'beta', 'rho(beta)', 'bigp', 't1(beta)'])

# Plotting rho(e) vs e
plt.figure(figsize=(8, 6))
plt.plot(df['e'], df['rho(e)'], marker='o', linestyle='-', label='rho(e)')
plt.plot(energy_grid, spectrum_data, marker='x', linestyle='-', label='Spectrum', color='red')
plt.title('rho(e) vs e and Spectrum')
plt.xlabel('e')
plt.ylabel('rho(e) / Spectrum')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['beta'], df['t1(beta)'], marker='o', linestyle='-', label='T1(beta)')
plt.plot(beta, np.exp(ln_T1_beta), label='ln(T1_beta)', marker='o', linestyle='-')
plt.xlim(0,10)
plt.ylim(-10,10)
plt.title('T1(beta) vs beta and Spectrum')
plt.xlabel('beta')
plt.ylabel('T1(beta)')
# plt.yscale('log')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to replace -inf/inf with 0
def replace_inf_values(array):
    return np.where(np.isinf(array), 0, array)

# Load data from ln_T1_debug.txt
data = np.loadtxt('T1_beta.txt', delimiter='\t', skiprows=1)

# Extract columns
beta = data[:, 0]
P_beta = data[:, 1]
ln_T1_beta = data[:, 2]

# Replace -inf/inf with 0
P_beta = replace_inf_values(P_beta)
ln_T1_beta = replace_inf_values(ln_T1_beta)

# Plot ln(P_beta) and ln(T1_beta)
plt.figure(figsize=(10, 6))
plt.figure(figsize=(8, 6))
plt.plot(df['beta'], df['bigp'], marker='o', linestyle='-', label='bigp')
plt.plot(beta, P_beta, label='P_beta', marker='o', linestyle='-')
plt.xlim(0,10)
plt.ylim(-10,10)
plt.title('T1(beta) vs beta and Spectrum')
plt.xlabel('beta')
plt.ylabel('T1(beta)')
# plt.yscale('log')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 9
#       6     return np.where(np.isinf(array), 0, array)
#       8 # Load data from ln_T1_debug.txt
# ----> 9 data = np.loadtxt('T1_beta.txt', delimiter='\t', skiprows=1)
#      11 # Extract columns
#      12 beta = data[:, 0]
#
# File ~/mambaforge/envs/endftk/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# File ~/mambaforge/envs/endftk/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:1036, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1033     data = _preprocess_comments(data, comments, encoding)
#    1035 if read_dtype_via_object_chunks is None:
# -> 1036     arr = _load_from_filelike(
#    1037         data, delimiter=delimiter, comment=comment, quote=quote,
#    1038         imaginary_unit=imaginary_unit,
#    1039         usecols=usecols, skiplines=skiplines, max_rows=max_rows,
#    1040         converters=converters, dtype=dtype,
#    1041         encoding=encoding, filelike=filelike,
#    1042         byte_converters=byte_converters)
#    1044 else:
#    1045     # This branch reads the file into chunks of object arrays and then
#    1046     # casts them to the desired actual dtype.  This ensures correct
#    1047     # string-length and datetime-unit discovery (like `arr.astype()`).
#    1048     # Due to chunking, certain error reports are less clear, currently.
#    1049     if filelike:
#
# ValueError: could not convert string '4.84621e-06 30088.8' to float64 at row 0, column 1.
